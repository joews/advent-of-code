# %%
# Part 1
def parse(input_str):
    grids = input_str.split("\n\n")
    return [parse_grid(g) for g in grids]

def parse_grid(grid):
    return [list(line) for line in grid.splitlines()]

def dump_grid(grid, visited=set()):
    for y in range(len(grid)):
        for x in range(len(grid[y])):
            print(grid[y][x], end="")
        print("")

def col(grid, x):
    return [grid[y][x] for y in range(len(grid))]

# def find_v_line(grid):
#     center = -1
#     max_span = -1

#     # Start by finding a pair of adjacent identical columns,
#     # then step outwards to check the symmetry.
#     # There may be several matching pairs, so find the one with the largest span.
#     for x in range(1, len(grid[0]) - 1):
#         if col(grid, x - 1) == col(grid, x):
#             n = 1
#             while x - n >= 0 and x + n < len(grid[0]):
#                 if col(grid, x - n) != col(grid, x + n):
#                     break

#                 n = n + 1
#             if n > max_span:
#                 max_span = n
#                 center = x
                
#     return center

# def find_h_line(grid):
#     center = -1
#     max_span = -1

#     # Start by finding a pair of adjacent identical columns,
#     # then step outwards to check the symmetry.
#     # There may be several matching pairs, so find the one with the largest span.
#     for y in range(1, len(grid) - 1):
#         if grid[y - 1] == grid[y]:
#             n = 1
#             while y - n >= 0 and y + n < len(grid):
#                 if grid[y - n] != grid[y + n]:
#                     break

#                 n = n + 1
#             if n > max_span:
#                 max_span = n
#                 center = y

                
#     return center

# def find_v_line2(grid):
#     center = -1
#     max_span = 1

#     width = len(grid[0])

#     for start in range(width):
#         for w in range(width - start - 1):
#             end = width - 1 - w
#             curr_s = start - 1
#             curr_e = end + 1

#             while curr_e - curr_s > 1:
#                 curr_s += 1
#                 curr_e -= 1

#                 if col(grid, curr_s) != col(grid, curr_e):
#                     break
#             else:
#                 span = end - start + 1
#                 if span > max_span:
#                     # print(("found at", start, end, span, curr_s, curr_e))
#                     max_span = span
#                     center = curr_e == curr_s and curr_s or curr_s + 1

#     return (center, max_span)

# def find_h_line2(grid):
#     center = -1
#     max_span = 1

#     height = len(grid)

#     for start in range(height):
#         for h in range(height - start - 1):
#             end = height - 1 - h
#             curr_s = start - 1
#             curr_e = end + 1

#             while curr_e - curr_s > 1:
#                 curr_s += 1
#                 curr_e -= 1

#                 if grid[curr_s] != grid[curr_e]:
#                     break
#             else:
#                 span = end - start + 1
#                 if span > max_span:
#                     # print(("found at", start, end, span, curr_s, curr_e))
#                     max_span = span
#                     center = curr_e == curr_s and curr_s or curr_s + 1
    
#     return (center, max_span)

def find_v_line_3(grid):
    # Start with the largest possible span, and step down until we find a match.
    width = len(grid[0])

    for span in range(width - 1, 1, -1):
        for start in range(width - span):
            # Is this span a match?
            
            end = start + span
            mid = start + span // 2
            for i in range(mid - start + 1):
                print(width, start, end, mid)
                if col(grid, start + i) != col(grid, end - i):
                    break
            else:
                return (mid, span + 1)
            
    return (-1, 1)

def find_h_line_3(grid):
    # Start with the largest possible span, and step down until we find a match.
    height = len(grid)

    for span in range(height - 1, 1, -1):
        for start in range(height - span):
            # Is this span a match?
            
            end = start + span
            mid = start + span // 2
            for i in range(mid - start + 1):
                if grid[start + i] != grid[end - i]:
                    break
            else:
                return (mid, span + 1)
            
    return (-1, 1)


def find_line(grid):
    (v, v_span) = find_v_line_3(grid)
    (h, h_span) = find_h_line_3(grid)

    if v_span > 0 and v_span > h_span:
        return v + 1
    elif h_span > 0:
        return (h + 1) * 100
    else:
        print("---------------------")
        print("No line found in grid")
        dump_grid(grid)
        print("---------------------")
        # raise Exception("No line found in grid")
  
        return -1


grids = parse(input_str)

# TODO WH
# error detecting mid line position depending on odd/even

grid = grids[1]
# print("v", find_v_line_3(grid))
print("h", find_h_line_3(grid))

# sum = 0
# for grid in grids:
#     # print(find_line(grid))
#     sum += find_line(grid)

# print("Part 1:", sum)

# 29217 low
# 35493 wrong
# 40022 high
# Out:
# h (4, 7)

# %%
# Test input
input_str="""
#.##..##.
..#.##.#.
##......#
##......#
..#.##.#.
..##..##.
#.#.##.#.

#...##..#
#....#..#
..##..###
#####.##.
.........
#####.##.
..##..###
#....#..#
""".strip()

# #....#..#
# ..##..###
# #####.##.
# .........
# #####.##.
# ..##..###
# #....#..#

# %%
# Input
input_str="""
...##.#
.##.###
.##.###
...##.#
#...###
.#..##.
##.##.#
...####
#.#.###
#....#.
..#.##.
..#.##.
#....#.
#.#.#.#
...####

###..##.######.##
..#..#.#......#.#
#.##.#..#.##.#..#
#.#.##.#..##..#.#
#..#...###..###..
#..#...###..###..
#.#.##.#..##..#.#
#.##.#..#.##.#..#
..#..#.#......#.#
###..##.######.##
...#.#..######..#
..###....#..#..#.
#.###....#..#....
##.#####.#..#.###
...#.....####....
..#...#.#.##.#.#.
...###.#......#.#

##.##.#####
#.####.#..#
#.####.#..#
##.##.###.#
########...
.#....#....
###..#####.

..#.#.#...####.
..#.#...#....##
##.##.#..##....
...#..#.....#..
##......#.##.#.
..####.#.#.#...
..####.#.###...

.#..#.##.
##..####.
.#..#..#.
..##....#
.#..#..#.
.#..#.###
........#
......#.#
##..##.##
##..##.#.
##..##...
##..##.##
......#.#
........#
.#..#.###

....###...#..##
#..####..##..##
.###..###.#.###
...####...#####
#..#..#..##..##
#.##..##.#.....
#........#.##..

.#.#.#.
.#.#.#.
##.#.##
#.#.###
..##...
..#....
###.###
..#..#.
#.####.
.##.###
.##.###
#.####.
..##.#.
###.###
..#....

#..#.###.##.#
....#...#..#.
....#..#.##.#
....##.......
.##.##.######
####....#..#.
.##..##.#....
.##.#.#..##..
####.#...##..
.##.#.#.#..#.
.....#.######
.##.....#..#.
#..##.###..##

#....#.#.
####.##.#
#.##..###
##..#.###
.#....#.#
...##..##
##..#....
##..#....
...##..##
.#....#.#
##..#.###
#.##..###
####.##.#
#....#.#.
.#...#...
.#...#...
#....#.##

..##....#.#.##.
.####..#.##.##.
##..##..#.#####
##..##.#.#.....
#######..######
.#....####.....
.......#.#.####

..#.....#
.###.#.##
##...##..
#......#.
#.###..##
#.#.#..##
#......#.
#.##..##.
#.###.###
#.###.###
#.##..##.
#......#.
#.#.#..##
#.###..##
#......#.

#####....####
..##..##..##.
###..#..#..##
##..##..##..#
##..#....#..#
###...#....##
..###.##.###.
####.####.###
..##.####.##.
###.##..##.##
##...#..#...#

#.###.###.#
#.###.###.#
...##.#..##
#..#.....#.
.....##...#
#..##.##...
...#.#.....
###.#...#.#
..#.#.##..#
#.#...#....
#.#...#....
..#.#.##..#
###.#...#.#
...#.#.....
#..##.#....
.....##...#
#..#.....#.

###.#..####..
###.#..#.##..
###.#..#.##..
###.#..####..
.#.#..#.#...#
.#....#..###.
#...##..#####

..#.###.#.####.
.....###.###.##
