# %%
# Part 1
import heapq

walls = set()
goal = (-1, -1)
start = (-1, -1)
orientation = (0, 1)

for (grid_y, row) in enumerate(input_str.splitlines()):
    for (grid_x, c) in enumerate(row):
        if c == "#":
            walls.add((grid_y, grid_x))
        elif c == "S":
            start = (grid_y, grid_x)
        elif c == "E":
            goal = (grid_y, grid_x)

def adjacent(node):
    y, x = node
    oy, ox = orientation
    out = []

    for (dy, dx) in [(1, 0), (0, 1), (-1, 0), (0, -1)]:
        if ox == 0 and oy == -1 * dy or oy == 0 and ox == -1 * dx:
            continue

        ny, nx = y + dy, x + dx
        if (ny, nx) not in walls:
            cost = (dy, dx) == orientation and 1 or 1001
            out.append(((ny, nx), cost))

    return out

def distance(a, b):
    return abs(a[1] - b[1]) + abs(a[0] - b[0])

open = []
closed = set()
parents = {}
node_cost = { start: 0 }

heapq.heappush(open, (0, start))

while len(open):
    f, node = heapq.heappop(open)
    closed.add(node)

    if node in parents:
        orientation = (node[0] - parents[node][0], node[1] - parents[node][1])

    if node == goal:
        print(node_cost[goal])
        print("ok")
        break
        

    for (n, cost_n) in adjacent(node):
        if (n in closed):
            continue

        node_cost[n] = node_cost[node] + cost_n
        parents[n] = node

        f_score = node_cost[n] + distance(n, goal)
        heapq.heappush(open, (f_score, n))

print("end")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 start = (-1, -1)
#       7 orientation = (0, 1)
# ----> 9 for (grid_y, row) in enumerate(input_str.splitlines()):
#      10     for (grid_x, c) in enumerate(row):
#      11         if c == "#":
#
# NameError: name 'input_str' is not defined

# %%
# Part 2 attempt 2
# Part 1
import heapq
from collections import defaultdict

walls = set()
goal = (-1, -1)
start = (-1, -1)
orientation = (0, 1)

for (grid_y, row) in enumerate(input_str.splitlines()):
    for (grid_x, c) in enumerate(row):
        if c == "#":
            walls.add((grid_y, grid_x))
        elif c == "S":
            start = (grid_y, grid_x)
        elif c == "E":
            goal = (grid_y, grid_x)

def adjacent(node):
    y, x = node
    oy, ox = orientation
    out = []

    for (dy, dx) in [(1, 0), (0, 1), (-1, 0), (0, -1)]:
        if ox == 0 and oy == -1 * dy or oy == 0 and ox == -1 * dx:
            continue

        ny, nx = y + dy, x + dx
        if (ny, nx) not in walls:
            cost = (dy, dx) == orientation and 1 or 1001
            out.append(((ny, nx), cost))

    return out

def distance(a, b):
    return abs(a[1] - b[1]) + abs(a[0] - b[0])

open = []
# closed = set()
visited = {}
parents = {}
all_parents = defaultdict(list)
node_cost = { start: 0 }

min_cost = 66404

heapq.heappush(open, (0, start))

# experimental
path_stack = []

while len(open):
    f, node = heapq.heappop(open)
    # closed.add(node)

    # print("still trying")

    if node_cost[node] > min_cost:
        # print("early")
        continue

    # if node in visited and visited[node] <= node_cost[node]:
    #     continue

    visited[node] = node_cost[node]

    # path_stack.append(str(node))

    if node in parents:
        orientation = (node[0] - parents[node][0], node[1] - parents[node][1])

    if node == goal:
        print("found shortest path", node_cost[goal])
        
        if node_cost[goal] < min_cost:
            min_cost = node_cost[goal]

        # print(path_stack)

        # p = node
        # while parents[p] != start:
        #     # print(parents[p])
        #     p = parents[p]


        # break
        

    for (n, cost_n) in adjacent(node):
        # if (n in visited):
        #     if node_cost[node] <= node_cost[all_parents[n][0]]:
        #     # print("aother")
        #         if not node in all_parents[n]:
        #             all_parents[n].append(node)
        #     continue

        n_cost = node_cost[node] + cost_n

        if n in visited: # and visited[n] < n_cost:
            # we found another way to get to the same node for the same cost
            if node_cost[node] <= node_cost[all_parents[n][0]]:
                all_parents[n].append(node)
                print("another one")
        else:

            node_cost[n] = n_cost

            # if len(all_parents[n]) == 0 or node_cost[node] <= node_cost[all_parents[n][0]]:
            #     if len(all_parents[n]) > 1:
            #         print(len(all_parents[n]))

            #     all_parents[n].append(node)
                # print("another one")



            # store the most recent parent only for orientation (??)
            # if n in parents:
            #     print("parent already", parents[n], node_cost[parents[n]], parents[node], node_cost[node])

            parents[n] = node

            if not all_parents[n] or node_cost[node] <= node_cost[all_parents[n][0]]:
                # print("aother")
                if not node in all_parents[n]:
                    all_parents[n].append(node)
    



            f_score = node_cost[n] + distance(n, goal)
            heapq.heappush(open, (f_score, n))

        

    # path_stack.pop()

print("end")

ns = set()

stack = [goal]

while stack:
    n = stack.pop()
    ns.add(n)

    if n == start:
        break

    # print (n, all_parents[n])
    for p in all_parents[n]:
        if p not in ns and p != start:
            stack.append(p)

print("SOLUTION")
print(len(ns) + 1)
# Out:
# found shortest path 7036
# end
# SOLUTION
# 37

# %%
# Part 2
import heapq

walls = set()
goal = (-1, -1)
sy, sx = -1, -1
orientation = (0, 1)


class Node:
    def __init__(self, y, x, g=0):
        self.y = y
        self.x = x
        self.g = g

    def __lt__(self, other):
        return self.f < other.f

    def __eq__(self, other):
        return self.y == other.y and self.x == other.x

    def __hash__(self):
        return hash((self.y, self.x))


for (grid_y, row) in enumerate(input_str.splitlines()):
    for (grid_x, c) in enumerate(row):
        if c == "#":
            walls.add((grid_y, grid_x))
        elif c == "S":
            sy, sx = grid_y, grid_x
        elif c == "E":
            goal = Node(grid_y, grid_x, -1)

def adjacent(node):
    oy, ox = orientation
    out = []

    for (dy, dx) in [(1, 0), (0, 1), (-1, 0), (0, -1)]:
        if ox == 0 and oy == -1 * dy or oy == 0 and ox == -1 * dx:
            continue

        # ny, nx = node.y + dy, node.x + dx
        ny, nx = node[0] + dy, node[1] + dx
        if (ny, nx) not in walls:
            cost = (dy, dx) == orientation and 1 or 1001
            # out.append(Node(ny, nx, cost))
            out.append(((ny, nx), cost))

    return out

def distance(n1, n2):
    return abs(n1.y - n2.y) + abs(n1.x - n2.x)

start = (sy, sx)
stack = [start]
goal = (goal.y, goal.x)
i = 0

node_cost = { }
node_cost[start] = 0
print(node_cost)

MAX = 66404

while stack and i < 10000000:
    node = stack.pop()

    if (node == goal):
        print("found the goal", node, len(stack))
        print(stack)
        print(node_cost[goal])
        break

    if (node_cost[node] >= MAX):
        # print("too expensive")
        continue

    for (n, step_cost) in adjacent(node):
        if not n in stack:
            n_cost = step_cost + node_cost[node]

            # if we already visited this node for lower total cost, ignore it
            # if n in node_cost and node_cost[n] <= n_cost:
            #     continue

            node_cost[n] = n_cost
            stack.append(n)

    i+=1

print("end")
print(len(stack))

# next_node_id = 0

# def get_node(y, x, g):
#     return Node(y, x, g)

# open = []
# # closed = set()
# visited = {}
# parents = {}
# # node_cost = {}

# min_cost = float("inf")

# nodes_on_shortest = set()

# start = Node(sy, sx, 0)
# # node_cost[start] = 0
# heapq.heappush(open, (0, start))



# while len(open):
#     f, node = heapq.heappop(open)
#     # print("enter", node)
#     # closed.add(node)

#     if node.g > min_cost:
#         continue

#     visited[node] = node.g

#     # if node_cost[node] > min_cost:
#     #     continue

#     if node in parents:
#         orientation = (node.y - parents[node].y, node.x - parents[node].x)

#     if node == goal:
#         print(node.g)
#         min_cost = node.g

#         next = node
#         print(start)
#         i = 0
#         while next != start :
#             # print(parents[next])
#             nodes_on_shortest.add(next)
#             next = parents[next]
#             i += 1
#         print("done")
#         print(len(nodes_on_shortest))
        

#     for n in adjacent(node):
#         if n in visited and visited[n] < n.g + node.g:
#             continue

#         # print("writing node cost for ", n)
#         n.g += node.g
#         parents[n] = node

#         f_score = n.g + distance(n, goal)
#         n.f = f_score
#         heapq.heappush(open, (f_score, n))
#         i += 1

# print("end")

# %%
# Test input 1
input_str="""
###############
#.......#....E#
#.#.###.#.###.#
#.....#.#...#.#
#.###.#####.#.#
#.#.#.......#.#
#.#.#####.###.#
#...........#.#
###.#.#####.#.#
#...#.....#.#.#
#.#.#.###.#.#.#
#.....#...#.#.#
#.###.#.#.#.#.#
#S..#.....#...#
###############
"""

# %%
# Test input 2
input_str="""
#################
#...#...#...#..E#
#.#.#.#.#.#.#.#.#
#.#.#.#...#...#.#
#.#.#.#.###.#.#.#
#...#.#.#.....#.#
#.#.#.#.#.#####.#
#.#...#.#.#.....#
#.#.#####.#.###.#
#.#.#.......#...#
#.#.###.#####.###
#.#.#...#.....#.#
#.#.#.#####.###.#
#.#.#.........#.#
#.#.#.#########.#
#S#.............#
#################"""

# %%
# Input
input_str = """
#############################################################################################################################################
#...........#.........#.#.......#...........................#.............#.........#...............#.....................#................E#
#.#########.#.#######.#.#.#####.#.###.###.#####.#.#.#####.###.#.#########.#.#####.#.#########.#####.#.#####.#####.#.#####.#.###.#.#######.#.#
#.#.......#.#.#...#...#.......#.#...#.#.......#.#.#.#.....#...#.#.........#.#.....#...........#...................#.#...#.#...#...#.#.......#
#.#.###.#.#.#.###.#.###########.###.#.#######.#.#.###.#.###.###.#.#########.#.#################.#.###.###.#.#.#.#.#.#.#.#.###.#####.#.#####.#
#.......#.#.#...#.........#.....#...#...#...#...#.#...#.#...#...#...........#.....#.........#...#.#.....#.#...#.#.#.#.#.#.......#...#...#.#.#
#.#####.###.#.#.#########.#.#####.#####.#.#.###.#.#.###.#.#####.#############.###.#.#######.#.#.#.#.###.###.###.#.#.#.#.###.###.###.###.#.#.#
#.....#.#...#.....................#...#.#.#.#.....#.#...#.....#.......#.....#...#...#...#...#.#...#.#.......#.#.#.#...#.#...#.....#.#...#...#
#.###.#.#.#.#.###.#.#########.#####.###.#.#.#.#.###.#########.#.###.###.###.###.#####.#.#.###.#####.#######.#.#.#######.#.#######.#.#.###.###
#.#...#...#.....#.#.#.....#...#...#...#.#.#.#.....#.........#.#.#...#.................................#.......#.........#.......#...#...#...#
#.#.###.###.#####.###.###.#.###.#.###.#.#.#.#####.#.#####.###.#.#.###.###.#.#######.#.#.#.#.#####.###.#.#####.#################.###.###.###.#
#.#.............#.....#...................#...#...#.#...#.....#.#...#.#...#.#...#...#.#.#...#.....#...#...............#.......#...#...#.#...#
